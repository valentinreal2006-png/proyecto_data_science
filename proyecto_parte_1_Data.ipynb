# %% [markdown]
# <a href="https://colab.research.google.com/github/valentinreal2006-png/proyecto_data_science/blob/main/proyecto_parte_1_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_autos:str = r"/autos_usados_argentina_datasci.csv"

autos_df:pd.DataFrame = pd.read_csv(df_autos, encoding='latin1',sep=';')

# %%
autos_df.head()
# Out:
#    ID  Fecha de Venta  Año del vehiculo       Marca  Modelo         Version  \
# 0   1           44824              2018  Volkswagen  Amarok            Base
# 1   2           44882              2010        Ford  Ranger        Highline
# 2   3           44616              2010      Toyota   Etios         Limited
# 3   4           44263              2021  Volkswagen     Gol  Pack Seguridad
# 4   5           45017              2017     Peugeot    2008     XEI 1.8 CVT
#
#   Tipo de Combustible transmisión  Kilometraje  Precio de Venta (ARS)  \
# 0               Nafta  Automatica        91249                2571886
# 1           Electrico  Automatica       102652                5904393
# 2           Electrico      Manual        85931                7558919
# 3             Hibrido  Automatica       162946                4166822
# 4               Nafta  Automatica       154693                6867438
#
#       Provincia       Ciudad Tipo de Vendedor Patente     Color  \
# ...

# %%
autos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6049 entries, 0 to 6048
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     6049 non-null   int64
#  1   Fecha de Venta         6049 non-null   int64
#  2   Año del vehiculo       6049 non-null   int64
#  3   Marca                  6049 non-null   object
#  4   Modelo                 6049 non-null   object
#  5   Version                6049 non-null   object
#  6   Tipo de Combustible    6049 non-null   object
#  7   transmisión            6049 non-null   object
#  8   Kilometraje            6049 non-null   int64
#  9   Precio de Venta (ARS)  6049 non-null   int64
#  10  Provincia              6049 non-null   object
#  11  Ciudad                 6049 non-null   object
#  12  Tipo de Vendedor       6049 non-null   object
#  13  Patente                6049 non-null   object
# ...
