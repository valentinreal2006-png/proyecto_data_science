# %% [markdown]
# <a href="https://colab.research.google.com/github/valentinreal2006-png/proyecto_data_science/blob/main/Proyecto_data_parte_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_autos:str = r"/autos_usados_argentina_datasci_s.csv"
autos_df = pd.read_csv(df_autos, encoding='latin-1', sep=';')

# %%
autos_df.head()
# Out:
#    ID  Fecha_de_Venta  Año_del_vehiculo       Marca  Modelo         Version  \
# 0   1           44824              2018  Volkswagen  Amarok            Base
# 1   2           44882              2010        Ford  Ranger        Highline
# 2   3           44616              2010      Toyota   Etios         Limited
# 3   4           44263              2021  Volkswagen     Gol  Pack Seguridad
# 4   5           45017              2017     Peugeot    2008     XEI 1.8 CVT
#
#   Tipo_de_Combustible transmisión  Kilometraje  Precio_de_Venta (ARS)  \
# 0               Nafta  Automatica        91249                2571886
# 1           Electrico  Automatica       102652                5904393
# 2           Electrico      Manual        85931                7558919
# 3             Hibrido  Automatica       162946                4166822
# 4               Nafta  Automatica       154693                6867438
#
#       Provincia       Ciudad Tipo_de_Vendedor Patente     Color  \
# ...

# %%
autos_df.set_index('ID', inplace=True)

# %%
autos_df.head()
# Out:
#     Fecha_de_Venta  Año_del_vehiculo       Marca  Modelo         Version  \
# ID
# 1            44824              2018  Volkswagen  Amarok            Base
# 2            44882              2010        Ford  Ranger        Highline
# 3            44616              2010      Toyota   Etios         Limited
# 4            44263              2021  Volkswagen     Gol  Pack Seguridad
# 5            45017              2017     Peugeot    2008     XEI 1.8 CVT
#
#    Tipo_de_Combustible transmisión  Kilometraje  Precio_de_Venta (ARS)  \
# ID
# 1                Nafta  Automatica        91249                2571886
# 2            Electrico  Automatica       102652                5904393
# 3            Electrico      Manual        85931                7558919
# 4              Hibrido  Automatica       162946                4166822
# 5                Nafta  Automatica       154693                6867438
#
#        Provincia       Ciudad Tipo_de_Vendedor Patente     Color  \
# ID
# ...

# %%
autos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6049 entries, 1 to 6049
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Fecha_de_Venta         6049 non-null   int64
#  1   Año_del_vehiculo       6049 non-null   int64
#  2   Marca                  6049 non-null   object
#  3   Modelo                 6049 non-null   object
#  4   Version                6049 non-null   object
#  5   Tipo_de_Combustible    6049 non-null   object
#  6   transmisión            6049 non-null   object
#  7   Kilometraje            6049 non-null   int64
#  8   Precio_de_Venta (ARS)  6049 non-null   int64
#  9   Provincia              6049 non-null   object
#  10  Ciudad                 6049 non-null   object
#  11  Tipo_de_Vendedor       6049 non-null   object
#  12  Patente                6049 non-null   object
#  13  Color                  6049 non-null   object
# ...

# %%
avg = (autos_df.groupby('Marca')['Año_del_vehiculo'].mean().round())

avg
# Out:
# Marca
# Chevrolet     2015.0
# Ford          2016.0
# Peugeot       2015.0
# Renault       2016.0
# Toyota        2015.0
# Volkswagen    2016.0
# Name: Año_del_vehiculo, dtype: float64
